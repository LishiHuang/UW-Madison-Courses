# %%
import numpy as np
import pandas as pd
import scipy.optimize as sp
import scipy.stats as st
import QuantLib as ql
import yfinance as yf
import datetime as dt
# from fredapi import Fred
import quandl
from arch import arch_model
# Out:
# c:\Users\Julia\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
start_date = dt.datetime(2024, 1, 1) - dt.timedelta(days=1*365)
end_date = dt.datetime(2024, 1, 1) 
sp500_data = yf.download('^GSPC', start=start_date, end=end_date)
sp500 = sp500_data['Close'].values
S0 = sp500[-1]

quandl.ApiConfig.api_key = '19PYgzG1hHNM7wZyy6NF' 
treasury_history = quandl.get("USTREASURY/YIELD.7", start_date=start_date, end_date=end_date, column_index=1)/100
current_rate = float(treasury_history.iloc[-1].values)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# c:\Users\Julia\anaconda3\Lib\site-packages\yfinance\utils.py:771: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# C:\Users\Julia\AppData\Local\Temp\ipykernel_20256\2096188396.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   current_rate = float(treasury_history.iloc[-1].values)

# %%
# 设定起始和结束日期
start_date = dt.datetime(2024, 1, 1) - dt.timedelta(days=10*365)
end_date = dt.datetime(2024, 1, 1)

# 下载VIX数据
vix = yf.download('^VIX', start=start_date, end=end_date)
vix_data = vix['Close'].values

# 拟合GARCH模型
model = arch_model(vix_data, vol='Garch', p=1, q=1)  # 我们改为GARCH(1,1)模型
result = model.fit()

# 提取模型参数
omega = result.params['omega']
alpha = result.params['alpha[1]']
beta = result.params['beta[1]']

# 定义初始波动率和路径长度
initial_volatility = vix_data[-1]  # 初始波动率
T = 252 * 3  # 三年的交易日数量

# 初始化路径数组
volatility_path = np.zeros(T)
volatility_path[0] = initial_volatility

# 使用GARCH模型参数模拟路径
for t in range(1, T):
    # 使用GARCH方程模拟未来波动率
    volatility_path[t] = np.sqrt(omega + alpha * volatility_path[t-1]**2 + beta * vix_data[-t]**2)


for v in volatility_path:
    print(f"volatility path={v:.2f}")
# Out:
# c:\Users\Julia\anaconda3\Lib\site-packages\yfinance\utils.py:771: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 8350607948.4466305
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 1655161573.0919487
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 36337.3074492383
# Iteration:      4,   Func. Count:     25,   Neg. LLF: 26548.86690216142
# Iteration:      5,   Func. Count:     31,   Neg. LLF: 7181.730335525123
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 202275.36799239612
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 6853.853943451664
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 6800.925710541648
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 39672.31339770514
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 6792.864337703582
# Iteration:     11,   Func. Count:     64,   Neg. LLF: 6787.406695706052
# Iteration:     12,   Func. Count:     69,   Neg. LLF: 6786.831814567824
# Iteration:     13,   Func. Count:     74,   Neg. LLF: 6786.786569255784
# Iteration:     14,   Func. Count:     79,   Neg. LLF: 6786.780213812427
# Iteration:     15,   Func. Count:     84,   Neg. LLF: 6786.780088363003
# Iteration:     16,   Func. Count:     89,   Neg. LLF: 6786.780086566154
# Iteration:     17,   Func. Count:     93,   Neg. LLF: 6786.780086047161
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6786.780086566154
#             Iterations: 17
#             Function evaluations: 93
#             Gradient evaluations: 17
# volatility path=12.45
# volatility path=12.48
# volatility path=12.51
# volatility path=12.54
# volatility path=12.60
# volatility path=12.65
# volatility path=12.74
# volatility path=12.82
# volatility path=12.83
# volatility path=12.85
# volatility path=12.85
# volatility path=12.86
# volatility path=12.86
# volatility path=12.85
# volatility path=12.87
# volatility path=12.87
# volatility path=12.91
# volatility path=12.94
# volatility path=12.97
# volatility path=13.00
# volatility path=13.01
# volatility path=13.04
# volatility path=13.07
# volatility path=13.08
# volatility path=13.09
# volatility path=13.08
# volatility path=13.10
# volatility path=13.14
# volatility path=13.19
# volatility path=13.25
# volatility path=13.34
# volatility path=13.42
# volatility path=13.49
# volatility path=13.59
# volatility path=13.65
# volatility path=13.77
# volatility path=13.84
# volatility path=13.92
# volatility path=14.00
# volatility path=14.08
# volatility path=14.20
# volatility path=14.38
# volatility path=14.63
# volatility path=14.98
# volatility path=15.41
# volatility path=15.76
# volatility path=16.06
# volatility path=16.25
# volatility path=16.52
# volatility path=16.87
# volatility path=17.17
# volatility path=17.30
# volatility path=17.36
# volatility path=17.37
# volatility path=17.51
# volatility path=17.49
# volatility path=17.44
# volatility path=17.44
# volatility path=17.47
# volatility path=17.49
# volatility path=17.57
# volatility path=17.65
# volatility path=17.79
# volatility path=17.81
# volatility path=17.81
# volatility path=17.81
# volatility path=17.85
# volatility path=17.94
# volatility path=17.90
# volatility path=17.89
# volatility path=17.89
# volatility path=17.78
# volatility path=17.62
# volatility path=17.47
# volatility path=17.31
# volatility path=17.12
# volatility path=16.97
# volatility path=16.86
# volatility path=16.73
# volatility path=16.61
# volatility path=16.52
# volatility path=16.44
# volatility path=16.34
# volatility path=16.21
# volatility path=16.10
# volatility path=16.02
# volatility path=15.96
# volatility path=15.94
# volatility path=15.95
# volatility path=16.04
# volatility path=16.06
# volatility path=16.14
# volatility path=16.22
# volatility path=16.30
# volatility path=16.42
# volatility path=16.46
# volatility path=16.48
# volatility path=16.42
# volatility path=16.36
# volatility path=16.36
# volatility path=16.36
# volatility path=16.37
# volatility path=16.36
# volatility path=16.42
# volatility path=16.42
# volatility path=16.43
# volatility path=16.33
# volatility path=16.22
# volatility path=16.10
# volatility path=16.04
# volatility path=15.92
# volatility path=15.84
# volatility path=15.77
# volatility path=15.69
# volatility path=15.62
# volatility path=15.55
# volatility path=15.47
# volatility path=15.39
# volatility path=15.31
# volatility path=15.25
# volatility path=15.19
# volatility path=15.20
# volatility path=15.22
# volatility path=15.22
# volatility path=15.26
# volatility path=15.23
# volatility path=15.17
# volatility path=15.12
# volatility path=15.06
# volatility path=15.00
# volatility path=14.96
# volatility path=14.95
# volatility path=14.90
# volatility path=14.83
# volatility path=14.77
# volatility path=14.75
# volatility path=14.72
# volatility path=14.73
# volatility path=14.71
# volatility path=14.73
# volatility path=14.78
# volatility path=14.75
# volatility path=14.72
# volatility path=14.71
# volatility path=14.70
# volatility path=14.72
# volatility path=14.74
# volatility path=14.82
# volatility path=15.03
# volatility path=15.20
# volatility path=15.38
# volatility path=15.63
# volatility path=15.93
# volatility path=16.10
# volatility path=16.19
# volatility path=16.25
# volatility path=16.26
# volatility path=16.32
# volatility path=16.44
# volatility path=16.50
# volatility path=16.55
# volatility path=16.59
# volatility path=16.64
# volatility path=16.72
# volatility path=16.76
# volatility path=16.80
# volatility path=17.02
# volatility path=17.12
# volatility path=17.18
# volatility path=17.14
# volatility path=17.09
# volatility path=17.11
# volatility path=17.23
# volatility path=17.34
# volatility path=17.34
# volatility path=17.33
# volatility path=17.35
# volatility path=17.32
# volatility path=17.32
# volatility path=17.32
# volatility path=17.33
# volatility path=17.38
# volatility path=17.50
# volatility path=17.61
# volatility path=17.71
# volatility path=17.77
# volatility path=17.86
# volatility path=17.95
# volatility path=18.00
# volatility path=18.06
# volatility path=18.14
# volatility path=18.21
# volatility path=18.33
# volatility path=18.48
# volatility path=18.70
# volatility path=18.95
# volatility path=19.16
# volatility path=19.31
# volatility path=19.62
# volatility path=20.00
# volatility path=20.19
# volatility path=20.58
# volatility path=20.78
# volatility path=21.14
# volatility path=21.38
# volatility path=21.46
# volatility path=21.36
# volatility path=21.29
# volatility path=21.17
# volatility path=21.05
# volatility path=21.00
# volatility path=20.99
# volatility path=20.99
# volatility path=21.01
# volatility path=21.07
# volatility path=21.09
# volatility path=21.17
# volatility path=21.29
# volatility path=21.24
# volatility path=21.20
# volatility path=21.07
# volatility path=20.98
# volatility path=20.96
# volatility path=20.96
# volatility path=20.96
# volatility path=20.91
# volatility path=20.82
# volatility path=20.76
# volatility path=20.66
# volatility path=20.58
# volatility path=20.46
# volatility path=20.42
# volatility path=20.42
# volatility path=20.34
# volatility path=20.28
# volatility path=20.23
# volatility path=20.20
# volatility path=20.20
# volatility path=20.20
# volatility path=20.23
# volatility path=20.26
# volatility path=20.23
# volatility path=20.15
# volatility path=20.10
# volatility path=20.18
# volatility path=20.22
# volatility path=20.34
# volatility path=20.40
# volatility path=20.53
# volatility path=20.64
# volatility path=20.78
# volatility path=20.85
# volatility path=20.90
# volatility path=20.99
# volatility path=21.04
# volatility path=21.05
# volatility path=21.12
# volatility path=21.09
# volatility path=21.13
# volatility path=21.22
# volatility path=21.31
# volatility path=21.41
# volatility path=21.42
# volatility path=21.50
# volatility path=21.72
# volatility path=21.80
# volatility path=21.84
# volatility path=21.91
# volatility path=21.94
# volatility path=21.90
# volatility path=21.77
# volatility path=21.69
# volatility path=21.65
# volatility path=21.68
# volatility path=21.73
# volatility path=21.68
# volatility path=21.63
# volatility path=21.63
# volatility path=21.69
# volatility path=21.78
# volatility path=21.92
# volatility path=22.06
# volatility path=22.22
# volatility path=22.32
# volatility path=22.35
# volatility path=22.43
# volatility path=22.66
# volatility path=22.85
# volatility path=22.95
# volatility path=23.05
# volatility path=23.20
# volatility path=23.36
# volatility path=23.52
# volatility path=23.67
# volatility path=23.80
# volatility path=24.02
# volatility path=24.23
# volatility path=24.49
# volatility path=24.82
# volatility path=25.13
# volatility path=25.43
# volatility path=25.76
# volatility path=26.05
# volatility path=26.38
# volatility path=26.73
# volatility path=27.05
# volatility path=27.45
# volatility path=27.84
# volatility path=28.12
# volatility path=28.31
# volatility path=28.45
# volatility path=28.47
# volatility path=28.52
# volatility path=28.62
# volatility path=28.80
# volatility path=28.99
# volatility path=29.07
# volatility path=29.28
# volatility path=29.46
# volatility path=29.50
# volatility path=29.40
# volatility path=29.34
# volatility path=29.24
# volatility path=29.08
# volatility path=28.95
# volatility path=28.82
# volatility path=28.70
# volatility path=28.64
# volatility path=28.42
# volatility path=28.16
# volatility path=27.94
# volatility path=27.79
# volatility path=27.76
# volatility path=27.65
# volatility path=27.56
# volatility path=27.48
# volatility path=27.43
# volatility path=27.38
# volatility path=27.30
# volatility path=27.05
# volatility path=26.85
# volatility path=26.73
# volatility path=26.59
# volatility path=26.32
# volatility path=26.01
# volatility path=25.74
# volatility path=25.46
# volatility path=25.21
# volatility path=24.96
# volatility path=24.74
# volatility path=24.51
# volatility path=24.39
# volatility path=24.25
# volatility path=24.11
# volatility path=23.99
# volatility path=23.90
# volatility path=23.92
# volatility path=23.88
# volatility path=23.76
# volatility path=23.70
# volatility path=23.70
# volatility path=23.77
# volatility path=23.76
# volatility path=23.74
# volatility path=23.72
# volatility path=23.75
# volatility path=23.80
# volatility path=23.90
# volatility path=23.94
# volatility path=24.09
# volatility path=24.26
# volatility path=24.45
# volatility path=24.56
# volatility path=24.58
# volatility path=24.68
# volatility path=24.81
# volatility path=24.98
# volatility path=25.09
# volatility path=25.32
# volatility path=25.49
# volatility path=25.67
# volatility path=25.76
# volatility path=25.85
# volatility path=26.05
# volatility path=26.23
# volatility path=26.47
# volatility path=26.76
# volatility path=27.14
# volatility path=27.30
# volatility path=27.63
# volatility path=28.02
# volatility path=28.02
# volatility path=27.94
# volatility path=27.75
# volatility path=27.58
# volatility path=27.46
# volatility path=27.34
# volatility path=27.22
# volatility path=27.15
# volatility path=27.12
# volatility path=27.06
# volatility path=27.10
# volatility path=27.18
# volatility path=27.32
# volatility path=27.40
# volatility path=27.53
# volatility path=27.64
# volatility path=27.85
# volatility path=27.77
# volatility path=27.77
# volatility path=27.84
# volatility path=28.08
# volatility path=28.35
# volatility path=28.64
# volatility path=29.01
# volatility path=29.09
# volatility path=29.22
# volatility path=29.04
# volatility path=29.07
# volatility path=29.27
# volatility path=29.52
# volatility path=29.56
# volatility path=29.68
# volatility path=29.92
# volatility path=29.78
# volatility path=29.71
# volatility path=29.39
# volatility path=28.99
# volatility path=28.64
# volatility path=28.34
# volatility path=28.08
# volatility path=27.80
# volatility path=27.63
# volatility path=27.48
# volatility path=27.19
# volatility path=26.93
# volatility path=26.71
# volatility path=26.45
# volatility path=26.10
# volatility path=25.81
# volatility path=25.57
# volatility path=25.29
# volatility path=25.00
# volatility path=24.76
# volatility path=24.58
# volatility path=24.44
# volatility path=24.41
# volatility path=24.35
# volatility path=24.33
# volatility path=24.32
# volatility path=24.41
# volatility path=24.55
# volatility path=24.88
# volatility path=25.31
# volatility path=25.65
# volatility path=25.93
# volatility path=26.34
# volatility path=26.90
# volatility path=27.52
# volatility path=27.79
# volatility path=27.95
# volatility path=28.13
# volatility path=28.44
# volatility path=28.55
# volatility path=28.51
# volatility path=28.63
# volatility path=28.78
# volatility path=28.79
# volatility path=28.75
# volatility path=28.73
# volatility path=28.52
# volatility path=28.39
# volatility path=28.40
# volatility path=28.36
# volatility path=28.15
# volatility path=27.79
# volatility path=27.50
# volatility path=27.28
# volatility path=27.09
# volatility path=26.97
# volatility path=26.74
# volatility path=26.52
# volatility path=26.45
# volatility path=26.53
# volatility path=26.77
# volatility path=27.09
# volatility path=27.34
# volatility path=27.50
# volatility path=27.59
# volatility path=27.50
# volatility path=27.33
# volatility path=27.12
# volatility path=26.76
# volatility path=26.47
# volatility path=26.09
# volatility path=25.75
# volatility path=25.46
# volatility path=25.16
# volatility path=24.91
# volatility path=24.67
# volatility path=24.34
# volatility path=24.00
# volatility path=23.70
# volatility path=23.42
# volatility path=23.13
# volatility path=22.88
# volatility path=22.65
# volatility path=22.44
# volatility path=22.27
# volatility path=22.22
# volatility path=22.27
# volatility path=22.25
# volatility path=22.18
# volatility path=22.06
# volatility path=22.07
# volatility path=21.99
# volatility path=21.84
# volatility path=21.85
# volatility path=21.77
# volatility path=21.79
# volatility path=22.13
# volatility path=22.69
# volatility path=23.02
# volatility path=23.55
# volatility path=23.77
# volatility path=23.75
# volatility path=24.05
# volatility path=23.80
# volatility path=23.60
# volatility path=23.40
# volatility path=23.16
# volatility path=22.91
# volatility path=22.65
# volatility path=22.38
# volatility path=22.12
# volatility path=21.86
# volatility path=21.67
# volatility path=21.54
# volatility path=21.38
# volatility path=21.19
# volatility path=20.98
# volatility path=20.74
# volatility path=20.50
# volatility path=20.30
# volatility path=20.13
# volatility path=19.96
# volatility path=19.81
# volatility path=19.69
# volatility path=19.53
# volatility path=19.34
# volatility path=19.17
# volatility path=18.99
# volatility path=18.84
# volatility path=18.70
# volatility path=18.60
# volatility path=18.51
# volatility path=18.45
# volatility path=18.48
# volatility path=18.57
# volatility path=18.68
# volatility path=18.70
# volatility path=18.77
# volatility path=18.92
# volatility path=19.07
# volatility path=19.32
# volatility path=19.44
# volatility path=19.68
# volatility path=19.86
# volatility path=20.08
# volatility path=20.03
# volatility path=19.94
# volatility path=19.89
# volatility path=19.96
# volatility path=20.24
# volatility path=20.59
# volatility path=20.62
# volatility path=20.54
# volatility path=20.44
# volatility path=20.41
# volatility path=20.37
# volatility path=20.42
# volatility path=20.36
# volatility path=20.26
# volatility path=20.17
# volatility path=20.00
# volatility path=19.85
# volatility path=19.68
# volatility path=19.54
# volatility path=19.40
# volatility path=19.27
# volatility path=19.27
# volatility path=19.16
# volatility path=19.08
# volatility path=19.00
# volatility path=19.00
# volatility path=19.17
# volatility path=19.33
# volatility path=19.28
# volatility path=19.14
# volatility path=18.98
# volatility path=18.84
# volatility path=18.72
# volatility path=18.64
# volatility path=18.57
# volatility path=18.47
# volatility path=18.43
# volatility path=18.42
# volatility path=18.42
# volatility path=18.50
# volatility path=18.51
# volatility path=18.49
# volatility path=18.50
# volatility path=18.57
# volatility path=18.54
# volatility path=18.49
# volatility path=18.47
# volatility path=18.46
# volatility path=18.55
# volatility path=18.81
# volatility path=18.81
# volatility path=18.74
# volatility path=18.64
# volatility path=18.58
# volatility path=18.48
# volatility path=18.38
# volatility path=18.44
# volatility path=18.35
# volatility path=18.27
# volatility path=18.13
# volatility path=18.02
# volatility path=17.93
# volatility path=17.86
# volatility path=17.77
# volatility path=17.69
# volatility path=17.62
# volatility path=17.57
# volatility path=17.55
# volatility path=17.59
# volatility path=17.79
# volatility path=17.81
# volatility path=17.85
# volatility path=17.83
# volatility path=17.78
# volatility path=17.69
# volatility path=17.63
# volatility path=17.67
# volatility path=17.66
# volatility path=17.62
# volatility path=17.58
# volatility path=17.62
# volatility path=17.64
# volatility path=17.68
# volatility path=17.65
# volatility path=17.62
# volatility path=17.63
# volatility path=17.72
# volatility path=17.78
# volatility path=17.94
# volatility path=18.12
# volatility path=18.38
# volatility path=18.57
# volatility path=18.66
# volatility path=18.69
# volatility path=18.97
# volatility path=19.55
# volatility path=19.70
# volatility path=19.72
# volatility path=19.59
# volatility path=19.55
# volatility path=19.55
# volatility path=19.56
# volatility path=19.52
# volatility path=19.49
# volatility path=19.41
# volatility path=19.33
# volatility path=19.25
# volatility path=19.19
# volatility path=19.12
# volatility path=19.12
# volatility path=19.05
# volatility path=19.05
# volatility path=18.98
# volatility path=18.87
# volatility path=18.77
# volatility path=18.70
# volatility path=18.62
# volatility path=18.55
# volatility path=18.48
# volatility path=18.42
# volatility path=18.37
# volatility path=18.38
# volatility path=18.38
# volatility path=18.34
# volatility path=18.42
# volatility path=18.51
# volatility path=18.66
# volatility path=18.69
# volatility path=18.77
# volatility path=18.93
# volatility path=19.03
# volatility path=19.04
# volatility path=19.17
# volatility path=19.33
# volatility path=19.34
# volatility path=19.39
# volatility path=19.44
# volatility path=19.53
# volatility path=19.69
# volatility path=19.87
# volatility path=20.14
# volatility path=20.48
# volatility path=20.75
# volatility path=21.26
# volatility path=21.60
# volatility path=21.76
# volatility path=21.87
# volatility path=22.26
# volatility path=22.68
# volatility path=22.63
# volatility path=22.67
# volatility path=22.73
# volatility path=22.71
# volatility path=22.72
# volatility path=22.67
# volatility path=22.63
# volatility path=22.51
# volatility path=22.46
# volatility path=22.45
# volatility path=22.43
# volatility path=22.38
# volatility path=22.32
# volatility path=22.31
# volatility path=22.36
# volatility path=22.56
# volatility path=23.06
# volatility path=23.72
# volatility path=24.13
# volatility path=25.03
# volatility path=24.94
# volatility path=24.86
# volatility path=24.73
# volatility path=24.57
# volatility path=24.44
# volatility path=24.39
# volatility path=24.40
# volatility path=24.36
# volatility path=24.26
# volatility path=24.23
# volatility path=24.24
# volatility path=24.12
# volatility path=24.04
# volatility path=24.12
# volatility path=24.20
# volatility path=24.37
# volatility path=24.31
# volatility path=24.24

# %%
# 自定义支付函数类
class CustomPayoff(ql.Payoff):
    def __init__(self, g, G, S, Term, expected_payoff):
        ql.Payoff.__init__(self)
        print("3")
        self.g = g
        self.G = G
        self.S = S
        self.Term = Term
        self.expected_payoff = expected_payoff
        self.K1 = (1+self.g)**(self.Term)*self.expected_payoff  # low strike price
        self.K2 = (1+self.G)**(self.Term)*self.expected_payoff  # high strike price
        self.contract = self.expected_payoff / self.S
        print(f"K1={self.K1:.2f}, K2={self.K2:.2f}, contract={self.contract:.2f}, expected_payoff={self.expected_payoff:.2f}, S={self.S:.2f}, Term={self.Term}, G={self.G:.2f}, g={self.g:.2f}")

    def name(self):
        return "Custom Payoff"

    def __call__(self, price):
        return max(min(self.K2, price * self.contract), self.K1)


# 定义目标函数，用于牛顿法求解
def target_function(G, expected_payoff, g, S, Term):
    # 使用给定的参数构建支付函数
    print("1")
    payoff = CustomPayoff(g, G, S, Term, expected_payoff)
    print("2")
    # 构建QuantLib的日期和日历对象
    calculation_date = ql.Date(1, 1, 2024)
    ql.Settings.instance().evaluationDate = calculation_date
    calendar = ql.NullCalendar()
    day_count = ql.Actual365Fixed()
    # 构建期权对象
    exercise_date = ql.Date(1, 1, 2028)  # 假设期权到期日为2028年1月1日
    exercise = ql.EuropeanExercise(exercise_date)
    print("4")
    option = ql.VanillaOption(payoff, exercise)
    # 构建无风险利率曲线
    risk_free_rate = current_rate  # 当前无风险利率
    flat_curve = ql.FlatForward(calculation_date, ql.QuoteHandle(ql.SimpleQuote(risk_free_rate)), day_count)
    discount_curve = ql.YieldTermStructureHandle(flat_curve)
    # 计算期权价格
    spot_price = S0  #当前股价
    spot_handle = ql.QuoteHandle(ql.SimpleQuote(spot_price))
    process = ql.BlackScholesProcess(spot_handle, discount_curve, ql.BlackVolTermStructureHandle(ql.BlackConstantVol(calculation_date, calendar, 0.0, day_count)))
    engine = ql.AnalyticEuropeanEngine(process)
    option.setPricingEngine(engine)
    option_price = option.NPV()
    # 返回期权价格与期望支付之间的差值，用于求解参数
    return option_price

# 使用牛顿法求解参数
L = 200000  # 期望的期权支付
Term =3
g_list=[0,0.005,0.01,0.015,0.02]
for g in g_list:
    parameter_solution= sp.newton(lambda G: target_function(G, L, g, S0, Term)-L,g)
    # parameter_solution = sp.newton(target_function, initial_guess, args=(expected_payoff,g,S0,Term))
    print("Parameter Solution:", parameter_solution)
# Out:
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20256\3661351997.py in ?()
#      54 L = 200000  # 期望的期权支付
#      55 Term =3
#      56 g_list=[0,0.005,0.01,0.015,0.02]
#      57 for g in g_list:
# ---> 58     parameter_solution= sp.newton(lambda G: target_function(G, L, g, S0, Term)-L,g)
#      59     # parameter_solution = sp.newton(target_function, initial_guess, args=(expected_payoff,g,S0,Term))
#      60     print("Parameter Solution:", parameter_solution)
#
# c:\Users\Julia\anaconda3\Lib\site-packages\scipy\optimize\_zeros_py.py in ?(func, x0, fprime, args, tol, maxiter, fprime2, x1, rtol, full_output, disp)
#     355         else:
#     356             eps = 1e-4
#     357             p1 = x0 * (1 + eps)
#     358             p1 += (eps if p1 >= 0 else -eps)
# --> 359         q0 = func(p0, *args)
#     360         funcalls += 1
#     361         q1 = func(p1, *args)
#     362         funcalls += 1
#
# ~\AppData\Local\Temp\ipykernel_20256\3661351997.py in ?(G)
# ---> 58     parameter_solution= sp.newton(lambda G: target_function(G, L, g, S0, Term)-L,g)
#
# ~\AppData\Local\Temp\ipykernel_20256\3661351997.py in ?(G, expected_payoff, g, S, Term)
#      24 def target_function(G, expected_payoff, g, S, Term):
#      25     # 使用给定的参数构建支付函数
#      26     print("1")
# ---> 27     payoff = CustomPayoff(g, G, S, Term, expected_payoff)
#      28     print("2")
#      29     # 构建QuantLib的日期和日历对象
#      30     calculation_date = ql.Date(1, 1, 2024)
#
# ~\AppData\Local\Temp\ipykernel_20256\3661351997.py in ?(self, g, G, S, Term, expected_payoff)
#       3     def __init__(self, g, G, S, Term, expected_payoff):
# ----> 4         ql.Payoff.__init__(self)
#       5         print("3")
#       6         self.g = g
#       7         self.G = G
#
# c:\Users\Julia\anaconda3\Lib\site-packages\QuantLib\QuantLib.py in ?(self, *args, **kwargs)
#   16887     def __init__(self, *args, **kwargs):
# > 16888         raise AttributeError("No constructor defined")
#
# AttributeError: No constructor defined
