# %%
import numpy as np
import scipy.optimize as sp
import QuantLib as ql

# %%
import yfinance as yf
import datetime

start_date = datetime.datetime.now() - datetime.timedelta(days=2*365)
end_date = datetime.datetime.now()

sp500_data = yf.download('^GSPC', start=start_date, end=end_date)
vix_data = yf.download('^VIX', start=start_date, end=end_date)
common_dates = sp500_data.index.intersection(vix_data.index)
sp500 = sp500_data.loc[common_dates]['Close'].values
vix = vix_data.loc[common_dates]['Close'].values
kappa=2.5
delta=kappa/len(sp500)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# interest rate
treasury_data = yf.download('^IRX', period="2y")
irx = treasury_data['Close'] / 100 
r = np.log(1 + irx).iloc[-1]
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
vt=(vix/100)**2
#eatimates theta
def Xt(t,theta):
    return (vt[t+1] - vt[t] - kappa * (theta - vt[t]) * delta) / np.sqrt(delta * vt[t])
def avgXt(theta):
    return np.mean([Xt(t, theta) for t in range(len(vix)-1)])
theta_hat=sp.newton(lambda theta:avgXt(theta),10)

# %%
def Xt_simulation():
    simulations = []
    for _ in range(len(vt)-1):
        Xt=(vt[_+1] - vt[_] - kappa * (theta_hat - vt[_]) * delta) / np.sqrt(delta * vt[_])
        simulations.append(Xt)
    return simulations
Xt_simulation=Xt_simulation()
volvol=np.var(Xt_simulation)

# %%
#estimates mu
St=sp500
def Yt(t,mu):
    return (St[t+1] - St[t] - St[t] * mu * delta) / (St[t] * np.sqrt(delta * vt[t]))
def avgYt(mu):
    return np.mean([Yt(t, mu) for t in t_values])
mu_hat=sp.newton(lambda mu:avgYt(mu),10)

# %%
def Yt_simulation():
    simulations = []
    for _ in range(len(St)-1):
        Yt=(St[_+1] - St[_] - St[_] * mu_hat * delta) / (St[_] * np.sqrt(delta * vt[_]))
        simulations.append(Yt)
    return simulations
Yt_simulation=Yt_simulation()

# %%
#estimates rho
rho_hat=np.corrcoef(Xt_simulation,Yt_simulation)[0, 1]
rho_hat, theta_hat,volvol,mu_hat
# Out:
# (-0.7182839958091324,
#  0.044313263271683834,
#  0.13498477783275173,
#  0.07162271190052115)

# %%
today = ql.Date(datetime.date.today().day, datetime.date.today().month, datetime.date.today().year)
day_count=ql.Actual365Fixed()
maturity = today + ql.Period(1, ql.Years)

S0=sp500[-1]
v0=vt[-1]
strike= S0
div=0

initial_value=ql.QuoteHandle(ql.SimpleQuote(S0))
discount_curves=ql.YieldTermStructureHandle(ql.FlatForward(today,r,day_count))
divident_curves=ql.YieldTermStructureHandle(ql.FlatForward(today,div,day_count))
heston_process=ql.HestonProcess(discount_curves,divident_curves,initial_value,v0,kappa,theta_hat,volvol,rho_hat)
call_payoff=ql.PlainVanillaPayoff(ql.Option.Call,strike)
call_exercise=ql.EuropeanExercise(maturity)

option = ql.VanillaOption(call_payoff, call_exercise)
engine = ql.AnalyticHestonEngine(ql.HestonModel(heston_process), 0.0001, 1000)
option.setPricingEngine(engine)
price = option.NPV()


print(f"Option Price:{price}")
# Out:
# Option Price:530.4560396277269

# %%
def calculate_delta(option, underlying, volatility):
    epsilon = 0.001
    underlying_value = underlying.value()
    
    underlying.setValue(underlying_value * (1 + epsilon))
    price_up = option.NPV()
    
    underlying.setValue(underlying_value * (1 - epsilon))
    price_down = option.NPV()
    
    underlying.setValue(underlying_value)
    
    delta = (price_up - price_down) / (2 * underlying_value * epsilon)
    return delta

def calculate_vega(option, volatility):
    epsilon = 0.001
    volatility_value = volatility.value()
    
    volatility.setValue(volatility_value + epsilon)
    price_up = option.NPV()
    
    volatility.setValue(volatility_value - epsilon)
    price_down = option.NPV()

    volatility.setValue(volatility_value)
    
    vega = (price_up - price_down) / (2 * epsilon)
    return vega

# create option
maturity_date = maturity
spot_price = S0
strike_price = S0
initial_volatility = v0
option_type = ql.Option.Call
risk_free_rate = r
dividend_rate = 0
mean_reversion = theta_hat
volatility = volvol
correlation = rho_hat

option = ql.VanillaOption(ql.PlainVanillaPayoff(option_type, strike_price), ql.EuropeanExercise(maturity_date))

# set heston model 
day_count = ql.Actual365Fixed()
calculation_date = ql.Date(1, 1, 2024)
ql.Settings.instance().evaluationDate = calculation_date

underlying = ql.SimpleQuote(spot_price)
volatility_quote = ql.SimpleQuote(initial_volatility)
risk_free_curve = ql.FlatForward(calculation_date, risk_free_rate, day_count)
dividend_curve = ql.FlatForward(calculation_date, dividend_rate, day_count)
heston_process = ql.HestonProcess(ql.YieldTermStructureHandle(dividend_curve), ql.YieldTermStructureHandle(risk_free_curve), ql.QuoteHandle(underlying), initial_volatility, volatility, mean_reversion, volatility * volatility, correlation)

option.setPricingEngine(ql.AnalyticHestonEngine(ql.HestonModel(heston_process)))

# calculate Delta and Vega
delta = calculate_delta(option, underlying, volatility_quote)
vega = calculate_vega(option, volatility_quote)

print(f"Delta: {delta}, Vega: {vega}")
# Out:
# Delta: 0.3957502784424764, Vega: 0.0

# %%
def generate_stock_path(S0, maturity, r, kappa, theta, volvol, rho, n_steps, n_simulations, dt):
    np.random.seed(2024)
    Z1 = np.random.normal(size=(n_steps, n_simulations))
    Z2 = rho * Z1 + np.sqrt(1 - rho ** 2) * np.random.normal(size=(n_steps, n_simulations))
    
    S = np.zeros((n_steps + 1, n_simulations))
    v = np.zeros((n_steps + 1, n_simulations))
    S[0] = S0
    v[0] = theta
    #print(S0, maturity, r, kappa, theta, volvol, rho, n_steps, n_simulations, dt)
    
    for i in range(1, n_steps + 1):
        v[i] = np.maximum(v[i - 1] + kappa * (theta - v[i - 1]) * dt + volvol * np.sqrt(v[i - 1] * dt) * Z1[i - 1], 0)
        S[i] = S[i - 1] * np.exp((r - 0.5 * v[i - 1]) * dt + np.sqrt(v[i - 1] * dt) * Z2[i - 1])
    
    return S, v

# %%
def monte_carlo_simulation(S0, strike, maturity, r, kappa, theta, volvol, rho, n_steps, n_simulations):
    dt = maturity / n_steps
    
    S, v = generate_stock_path(S0, maturity, r, kappa, theta, volvol, rho, n_steps, n_simulations, dt)
    payoffs = np.maximum(S[-1] - strike, 0)
    option_price = np.exp(-r * maturity) * payoffs
    
    return np.mean(option_price)

# %%
option_price = monte_carlo_simulation(S0=S0, strike=strike, r=r, kappa=kappa, theta=theta_hat,volvol=volvol, rho=rho_hat, maturity=1, n_steps=250, n_simulations=10000)

# %%
option_price,S0,r,v0,volvol,strike
# Out:
# (555.0710891243482,
#  5022.2099609375,
#  0.05110177633905688,
#  0.0331604066656495,
#  0.13498477783275173,
#  5022.2099609375)

# %%
actual_price_list = [524.72, 493.10, 456.61, 447.42, 412.00]
actual_strike_list = [4975, 5000, 5025, 5050, 5100]

# %%
def objective_function(params):
    kappa, theta = params  
    total_error = 0
    for i in range(len(actual_price_list)):
        option_price = monte_carlo_simulation(S0=S0, strike=actual_strike_list[i], r=r, kappa=kappa, theta=theta, volvol=volvol, rho=rho_hat, maturity=1, n_steps=250, n_simulations=10000)
        error = (option_price - actual_price_list[i])**2
        total_error += error
        print(f"For strike price {actual_strike_list[i]}, Option price: {option_price}, Actual price: {actual_price_list[i]}, Error: {error}")
    print(f"Kappa:{kappa},Theta:{theta},Total error: {total_error}")
    return total_error

initial_guess = [2.5, 0.044]
bounds = [(1, None), (0, None)]
result = sp.minimize(objective_function, initial_guess, bounds=bounds, method='Nelder-Mead',options={'maxiter': 1000})

best_params = result.x
best_error = result.fun

print("Best parameters:", best_params)
print("Best error:", best_error)
# Out:
# For strike price 4975, Option price: 579.9487122505262, Actual price: 524.72, Error: 3050.2106568514228
# For strike price 5000, Option price: 565.920444323652, Actual price: 493.1, Error: 5302.817111494092
# For strike price 5025, Option price: 552.132705391085, Actual price: 456.61, Error: 9124.587245232013
# For strike price 5050, Option price: 538.5564524060773, Actual price: 447.42, Error: 8305.852957165182
# For strike price 5100, Option price: 511.9758763582225, Actual price: 412.0, Error: 9995.175853594588
# Kappa:2.5,Theta:0.044,Total error: 35778.6438243373
# For strike price 4975, Option price: 579.9345028977199, Actual price: 524.72, Error: 3048.6413302423143
# For strike price 5000, Option price: 565.9232153832231, Actual price: 493.1, Error: 5303.220698751302
# For strike price 5025, Option price: 552.1525730363497, Actual price: 456.61, Error: 9128.383262406222
# For strike price 5050, Option price: 538.5883132006076, Actual price: 447.42, Error: 8311.661331844072
# For strike price 5100, Option price: 512.0363390736536, Actual price: 412.0, Error: 10007.269135258995
# Kappa:2.625,Theta:0.044,Total error: 35799.175758502905
# For strike price 4975, Option price: 589.5650824656341, Actual price: 524.72, Error: 4204.884719974881
# For strike price 5000, Option price: 575.6454968553743, Actual price: 493.1, Error: 6813.759051100603
# For strike price 5025, Option price: 561.956504416837, Actual price: 456.61, Error: 11097.885992846654
# For strike price 5050, Option price: 548.4541933975712, Actual price: 447.42, Error: 10207.908235497816
# For strike price 5100, Option price: 522.0382848138634, Actual price: 412.0, Error: 12108.424124776911
# Kappa:2.5,Theta:0.0462,Total error: 44432.862124196865
# For strike price 4975, Option price: 570.1064751546545, Actual price: 524.72, Error: 2059.932126964068
# For strike price 5000, Option price: 555.9661805863446, Actual price: 493.1, Error: 3952.156661514894
# For strike price 5025, Option price: 542.087421564849, Actual price: 456.61, Error: 7306.389597374915
# For strike price 5050, Option price: 528.4435194215195, Actual price: 447.42, Error: 6564.810699449337
# For strike price 5100, Option price: 501.7264945115757, Actual price: 412.0, Error: 8050.843817335825
# Kappa:2.625,Theta:0.0418,Total error: 27934.13290263904
# For strike price 4975, Option price: 560.0302833900283, Actual price: 524.72, Error: 1246.8161130841086
# For strike price 5000, Option price: 545.7744912464434, Actual price: 493.1, Error: 2774.6020280716402
# For strike price 5025, Option price: 531.7858131295148, Actual price: 456.61, Error: 5651.402879683736
# For strike price 5050, Option price: 518.0530409489136, Actual price: 447.42, Error: 4989.0264736909
# For strike price 5100, Option price: 491.1836679215213, Actual price: 412.0, Error: 6270.053265505762
# Kappa:2.6875,Theta:0.03960000000000001,Total error: 20931.900760036147
# For strike price 4975, Option price: 560.0542586024096, Actual price: 524.72, Error: 1248.5098309819562
# For strike price 5000, Option price: 545.7829612705224, Actual price: 493.1, Error: 2775.4944082313586
# For strike price 5025, Option price: 531.7747206211111, Actual price: 456.61, Error: 5649.735226049682
# For strike price 5050, Option price: 518.0251624729422, Actual price: 447.42, Error: 4985.0889678305575
# For strike price 5100, Option price: 491.131274955409, Actual price: 412.0, Error: 6261.7586760685435
# Kappa:2.5625,Theta:0.03960000000000001,Total error: 20920.587109162097
# For strike price 4975, Option price: 549.7480254889122, Actual price: 524.72, Error: 626.4020598736355
# For strike price 5000, Option price: 535.3518563717215, Actual price: 493.1, Error: 1785.2193668565817
# For strike price 5025, Option price: 521.2062252277998, Actual price: 456.61, Error: 4172.672313680637
# For strike price 5050, Option price: 507.3314290112745, Actual price: 447.42, Error: 3589.379326172983
# For strike price 5100, Option price: 480.2695996365828, Actual price: 412.0, Error: 4660.73823453931
# Kappa:2.53125,Theta:0.03740000000000002,Total error: 14834.411301123146
# For strike price 4975, Option price: 528.2371328562893, Actual price: 524.72, Error: 12.370223528789886
# For strike price 5000, Option price: 513.5914992516309, Actual price: 493.1, Error: 419.90154157958966
# For strike price 5025, Option price: 499.2040539386571, Actual price: 456.61, Error: 1814.2534309292314
# For strike price 5050, Option price: 485.08241685356626, Actual price: 447.42, Error: 1418.4576432517906
# For strike price 5100, Option price: 457.66452892179416, Actual price: 412.0, Error: 2085.249201649375
# Kappa:2.71875,Theta:0.03300000000000003,Total error: 5750.232040938777
# For strike price 4975, Option price: 499.5228172371343, Actual price: 524.72, Error: 634.8980191852582
# For strike price 5000, Option price: 484.4843287189059, Actual price: 493.1, Error: 74.22979162387028
# For strike price 5025, Option price: 469.7367237314585, Actual price: 456.61, Error: 172.31087592203497
# For strike price 5050, Option price: 455.2460974206227, Actual price: 447.42, Error: 61.24780083707664
# For strike price 5100, Option price: 427.1604449783919, Actual price: 412.0, Error: 229.83909194284885
# Kappa:2.828125,Theta:0.027500000000000052,Total error: 1172.5255795110888
# For strike price 4975, Option price: 487.47541034503803, Actual price: 524.72, Error: 1387.1594585665023
# For strike price 5000, Option price: 472.2043801988935, Actual price: 493.1, Error: 436.6269268723955
# For strike price 5025, Option price: 457.2454411104254, Actual price: 456.61, Error: 0.4037854048186706
# For strike price 5050, Option price: 442.57519488743264, Actual price: 447.42, Error: 23.472136578758942
# For strike price 5100, Option price: 414.0955547377603, Actual price: 412.0, Error: 4.39134965894974
# Kappa:2.671875,Theta:0.02530000000000006,Total error: 1852.053657081425
# For strike price 4975, Option price: 426.44139382475726, Actual price: 524.72, Error: 9658.684431748467
# For strike price 5000, Option price: 409.98513071994614, Actual price: 493.1, Error: 6908.081495440444
# For strike price 5025, Option price: 393.8830680149771, Actual price: 456.61, Error: 3934.6679962536928
# For strike price 5050, Option price: 378.14069863244424, Actual price: 447.42, Error: 4799.621597976616
# For strike price 5100, Option price: 347.72219443163175, Actual price: 412.0, Error: 4131.636288684953
# Kappa:2.96875,Theta:0.015400000000000094,Total error: 29432.69181010417
# For strike price 4975, Option price: 522.7023434564221, Actual price: 524.72, Error: 4.070937927842774
# For strike price 5000, Option price: 507.9791853366649, Actual price: 493.1, Error: 221.39015628282303
# For strike price 5025, Option price: 493.5053569048997, Actual price: 456.61, Error: 1361.26736113993
# For strike price 5050, Option price: 479.2985970733581, Actual price: 447.42, Error: 1016.2449513655152
# For strike price 5100, Option price: 451.7373868472186, Actual price: 412.0, Error: 1579.059913445502
# Kappa:2.640625,Theta:0.03190000000000004,Total error: 4182.033320161613
# For strike price 4975, Option price: 461.74538418115674, Actual price: 524.72, Error: 3965.8022375309074
# For strike price 5000, Option price: 446.05838349144153, Actual price: 493.1, Error: 2212.9136837382825
# For strike price 5025, Option price: 430.67923122356234, Actual price: 456.61, Error: 672.404769337075
# For strike price 5050, Option price: 415.6071569884993, Actual price: 447.42, Error: 1012.05698047439
# For strike price 5100, Option price: 386.4356186984238, Actual price: 412.0, Error: 653.5375913323784
# Kappa:2.859375,Theta:0.02090000000000007,Total error: 8516.715262413032
# For strike price 4975, Option price: 508.40499278770005, Actual price: 524.72, Error: 266.1794603374002
# For strike price 5000, Option price: 493.49720229770384, Actual price: 493.1, Error: 0.15776966530118902
# For strike price 5025, Option price: 478.84669978703994, Actual price: 456.61, Error: 494.4708174189414
# For strike price 5050, Option price: 464.46002687997014, Actual price: 447.42, Error: 290.3625160701045
# For strike price 5100, Option price: 436.56397249634136, Actual price: 412.0, Error: 603.388744801015
# Kappa:2.6953125,Theta:0.029150000000000047,Total error: 1654.5593082927624
# For strike price 4975, Option price: 519.8190500784871, Actual price: 524.72, Error: 24.019310133177896
# For strike price 5000, Option price: 505.08849317296745, Actual price: 493.1, Error: 143.72396855828651
# For strike price 5025, Option price: 490.6010251032833, Actual price: 456.61, Error: 1155.389787572034
# For strike price 5050, Option price: 476.3911017196253, Actual price: 447.42, Error: 839.3247348488741
# For strike price 5100, Option price: 448.82382137787425, Actual price: 412.0, Error: 1355.993820869589
# Kappa:2.8515625,Theta:0.031350000000000044,Total error: 3518.4516219819616
# For strike price 4975, Option price: 495.82810061081796, Actual price: 524.72, Error: 834.7418503146193
# For strike price 5000, Option price: 480.707600413806, Actual price: 493.1, Error: 153.57156750390163
# For strike price 5025, Option price: 465.89291516765115, Actual price: 456.61, Error: 86.1725140098076
# For strike price 5050, Option price: 451.33602121666235, Actual price: 447.42, Error: 15.335222169349512
# For strike price 5100, Option price: 423.1087360682773, Actual price: 412.0, Error: 123.40401703464553
# Kappa:2.716796875,Theta:0.026812500000000055,Total error: 1213.2251710323235
# For strike price 4975, Option price: 486.62116587520484, Actual price: 524.72, Error: 1451.5211616686584
# For strike price 5000, Option price: 471.3631766028711, Actual price: 493.1, Error: 472.4894913979723
# For strike price 5025, Option price: 456.4165209289792, Actual price: 456.61, Error: 0.03743415092307859
# For strike price 5050, Option price: 441.7580254346377, Actual price: 447.42, Error: 32.0579559788096
# For strike price 5100, Option price: 413.31463439055665, Actual price: 412.0, Error: 1.72826358083425
# Kappa:2.849609375,Theta:0.025162500000000063,Total error: 1957.8343067771975
# For strike price 4975, Option price: 503.0810041698522, Actual price: 524.72, Error: 468.246140537156
# For strike price 5000, Option price: 488.09073497278246, Actual price: 493.1, Error: 25.092736112905
# For strike price 5025, Option price: 473.37782685335844, Actual price: 456.61, Error: 281.160017384208
# For strike price 5050, Option price: 458.9237915408559, Actual price: 447.42, Error: 132.33721981546776
# For strike price 5100, Option price: 430.9009514713414, Actual price: 412.0, Error: 357.2459665220021
# Kappa:2.73388671875,Theta:0.02815312500000005,Total error: 1264.0820803717388
# For strike price 4975, Option price: 492.1958780838403, Actual price: 524.72, Error: 1057.8185064172226
# For strike price 5000, Option price: 477.0259667480089, Actual price: 493.1, Error: 258.3745449861164
# For strike price 5025, Option price: 462.168877842033, Actual price: 456.61, Error: 30.90112286264529
# For strike price 5050, Option price: 447.57617716341576, Actual price: 447.42, Error: 0.024391306372589273
# For strike price 5100, Option price: 419.2795040816597, Actual price: 412.0, Error: 52.99117967490016
# Kappa:2.81103515625,Theta:0.02615937500000006,Total error: 1400.109745247257
# For strike price 4975, Option price: 500.39012877464836, Actual price: 524.72, Error: 591.942633842195
# For strike price 5000, Option price: 485.35594078505216, Actual price: 493.1, Error: 59.970453124618984
# For strike price 5025, Option price: 470.610057408084, Actual price: 456.61, Error: 196.0016074296474
# For strike price 5050, Option price: 456.1213592050793, Actual price: 447.42, Error: 75.71365201581752
# For strike price 5100, Option price: 428.0328889766355, Actual price: 412.0, Error: 257.05352893711984
# Kappa:2.753173828125,Theta:0.027654687500000052,Total error: 1180.6818753493988
# For strike price 4975, Option price: 504.0451939021729, Actual price: 524.72, Error: 427.44760718274927
# For strike price 5000, Option price: 489.0873806252963, Actual price: 493.1, Error: 16.101114246247654
# For strike price 5025, Option price: 474.40447157936, Actual price: 456.61, Error: 316.64321878865053
# For strike price 5050, Option price: 459.9815553794261, Actual price: 447.42, Error: 157.79267355038797
# For strike price 5100, Option price: 432.02877345067196, Actual price: 412.0, Error: 401.15176593834207
# Kappa:2.864501953125,Theta:0.02834218750000005,Total error: 1319.1363797063775
# For strike price 4975, Option price: 497.89804504793153, Actual price: 524.72, Error: 719.4172674507917
# For strike price 5000, Option price: 482.8197059263049, Actual price: 493.1, Error: 105.68444624165124
# For strike price 5025, Option price: 468.0397299012635, Actual price: 456.61, Error: 130.63872561583693
# For strike price 5050, Option price: 453.51626707484695, Actual price: 447.42, Error: 37.164472247862804
# For strike price 5100, Option price: 425.35941036955285, Actual price: 412.0, Error: 178.47384542211614
# Kappa:2.75372314453125,Theta:0.027194921875000055,Total error: 1171.378756978259
# For strike price 4975, Option price: 497.0232306435722, Actual price: 524.72, Error: 767.1110327831584
# For strike price 5000, Option price: 481.9419328568443, Actual price: 493.1, Error: 124.50246237117155
# For strike price 5025, Option price: 467.15924541218317, Actual price: 456.61, Error: 111.28657876646733
# For strike price 5050, Option price: 452.6337235677166, Actual price: 447.42, Error: 27.182913440563055
# For strike price 5100, Option price: 424.47922594427615, Actual price: 412.0, Error: 155.73108016829502
# Kappa:2.82867431640625,Theta:0.027040234375000055,Total error: 1185.8140675296552
# For strike price 4975, Option price: 499.55150123813917, Actual price: 524.72, Error: 633.4533299257916
# For strike price 5000, Option price: 484.5056363637155, Actual price: 493.1, Error: 73.86308631268979
# For strike price 5025, Option price: 469.7506540483465, Actual price: 456.61, Error: 172.6767888183254
# For strike price 5050, Option price: 455.252899076086, Actual price: 447.42, Error: 61.354307936148814
# For strike price 5100, Option price: 427.14821722163316, Actual price: 412.0, Error: 229.46848499378348
# Kappa:2.7720489501953125,Theta:0.027501074218750053,Total error: 1170.8159979867391
# For strike price 4975, Option price: 497.92799103079494, Actual price: 524.72, Error: 717.8117446059657
# For strike price 5000, Option price: 482.8410621389998, Actual price: 493.1, Error: 105.24580603586377
# For strike price 5025, Option price: 468.0543151188389, Actual price: 456.61, Error: 130.97234853928367
# For strike price 5050, Option price: 453.5235085146291, Actual price: 447.42, Error: 37.25281618814973
# For strike price 5100, Option price: 425.34721330739, Actual price: 412.0, Error: 178.1481030729689
# Kappa:2.6976470947265625,Theta:0.027195996093750056,Total error: 1169.4308184422318
# For strike price 4975, Option price: 497.12861452590414, Actual price: 524.72, Error: 761.2845523801495
# For strike price 5000, Option price: 482.01686764969213, Actual price: 493.1, Error: 122.83582269444133
# For strike price 5025, Option price: 467.2103255513831, Actual price: 456.61, Error: 112.36690179530528
# For strike price 5050, Option price: 452.6593589594813, Actual price: 447.42, Error: 27.450882306297054
# For strike price 5100, Option price: 424.4372630404919, Actual price: 412.0, Error: 154.68551193838653
# Kappa:2.6324081420898438,Theta:0.027043994140625055,Total error: 1178.6236711145798
# For strike price 4975, Option price: 499.580840917426, Actual price: 524.72, Error: 631.9773193789655
# For strike price 5000, Option price: 484.5265316085856, Actual price: 493.1, Error: 73.50436025858173
# For strike price 5025, Option price: 469.76472460467096, Actual price: 456.61, Error: 173.04677942473518
# For strike price 5050, Option price: 455.25948668215324, Actual price: 447.42, Error: 61.45755143965773
# For strike price 5100, Option price: 427.13522686828424, Actual price: 412.0, Error: 229.07509235443302
# Kappa:2.715972900390625,Theta:0.027502148437500054,Total error: 1169.0611028563733
# For strike price 4975, Option price: 500.4189269920802, Actual price: 524.72, Error: 590.5421493362509
# For strike price 5000, Option price: 485.37683347174095, Actual price: 493.1, Error: 59.64730122322128
# For strike price 5025, Option price: 470.6240120528448, Actual price: 456.61, Error: 196.39253381727946
# For strike price 5050, Option price: 456.1277561450169, Actual price: 447.42, Error: 75.82501708107961
# For strike price 5100, Option price: 428.019429755844, Actual price: 412.0, Error: 256.6221297024197
# Kappa:2.6970977783203125,Theta:0.02765576171875006,Total error: 1179.029131160251
# For strike price 4975, Option price: 497.9578015018197, Actual price: 524.72, Error: 716.215268456006
# For strike price 5000, Option price: 482.8622359243856, Actual price: 493.1, Error: 104.8118132679418
# For strike price 5025, Option price: 468.06875279113075, Actual price: 456.61, Error: 131.3030155282464
# For strike price 5050, Option price: 453.530220435988, Actual price: 447.42, Error: 37.33479377636501
# For strike price 5100, Option price: 425.3343381225302, Actual price: 412.0, Error: 177.80457316596218
# Kappa:2.641571044921875,Theta:0.027197070312500057,Total error: 1167.4694641945214
# For strike price 4975, Option price: 497.15927164509463, Actual price: 524.72, Error: 759.5937474528862
# For strike price 5000, Option price: 482.03788676890406, Actual price: 493.1, Error: 122.37034913758838
# For strike price 5025, Option price: 467.2245635540354, Actual price: 456.61, Error: 112.6689594426563
# For strike price 5050, Option price: 452.6662223499219, Actual price: 447.42, Error: 27.522848944819845
# For strike price 5100, Option price: 424.4237430703756, Actual price: 412.0, Error: 154.34939187870629
# Kappa:2.5763320922851562,Theta:0.027045068359375063,Total error: 1176.505296856657
# For strike price 4975, Option price: 499.6104452424692, Actual price: 524.72, Error: 630.4897401214384
# For strike price 5000, Option price: 484.54721108212044, Actual price: 493.1, Error: 73.15019827380378
# For strike price 5025, Option price: 469.7787946645461, Actual price: 456.61, Error: 173.41715291697815
# For strike price 5050, Option price: 455.265992364017, Actual price: 447.42, Error: 61.55959617621274
# For strike price 5100, Option price: 427.1220469581957, Actual price: 412.0, Error: 228.67630420587614
# Kappa:2.6598968505859375,Theta:0.027503222656250055,Total error: 1167.2929916943092
# For strike price 4975, Option price: 500.4483626798247, Actual price: 524.72, Error: 589.1123782021278
# For strike price 5000, Option price: 485.39725693306605, Actual price: 493.1, Error: 59.33225075519944
# For strike price 5025, Option price: 470.63787133169416, Actual price: 456.61, Error: 196.78117409856642
# For strike price 5050, Option price: 456.13392529751917, Actual price: 447.42, Error: 75.93249409074427
# For strike price 5100, Option price: 428.0057072272403, Actual price: 412.0, Error: 256.18266384413215
# Kappa:2.641021728515625,Theta:0.027656835937500054,Total error: 1177.34096099077
# For strike price 4975, Option price: 497.9878410824241, Actual price: 524.72, Error: 714.6083203945343
# For strike price 5000, Option price: 482.883219306038, Actual price: 493.1, Error: 104.38260774851568
# For strike price 5025, Option price: 468.0826698415017, Actual price: 456.61, Error: 131.62215329210196
# For strike price 5050, Option price: 453.53690421807096, Actual price: 447.42, Error: 37.41651721305409
# For strike price 5100, Option price: 425.3209087880701, Actual price: 412.0, Error: 177.44661094008282
# Kappa:2.5854949951171875,Theta:0.02719814453125006,Total error: 1165.476209588289
# For strike price 4975, Option price: 497.1901377019854, Actual price: 524.72, Error: 757.8933181476468
# For strike price 5000, Option price: 482.0590376701901, Actual price: 493.1, Error: 121.9028491682819
# For strike price 5025, Option price: 467.23842258440106, Actual price: 456.61, Error: 112.96336663260631
# For strike price 5050, Option price: 452.67237914045694, Actual price: 447.42, Error: 27.587486635107012
# For strike price 5100, Option price: 424.40976759478747, Actual price: 412.0, Error: 154.00233175663712
# Kappa:2.5202560424804688,Theta:0.027046142578125057,Total error: 1174.3493523402792
# For strike price 4975, Option price: 499.6400237319218, Actual price: 524.72, Error: 629.0052096073663
# For strike price 5000, Option price: 484.56774630158145, Actual price: 493.1, Error: 72.7993531741774
# For strike price 5025, Option price: 469.7929116456911, Actual price: 456.61, Error: 173.78915945809783
# For strike price 5050, Option price: 455.2722108709121, Actual price: 447.42, Error: 61.65721556126976
# For strike price 5100, Option price: 427.1083062323723, Actual price: 412.0, Error: 228.26091721113926
# Kappa:2.60382080078125,Theta:0.027504296875000056,Total error: 1165.5118550120505
# For strike price 4975, Option price: 498.01835168419916, Actual price: 524.72, Error: 712.9780227807113
# For strike price 5000, Option price: 482.90390976847044, Actual price: 493.1, Error: 103.96025600949295
# For strike price 5025, Option price: 468.09649709384746, Actual price: 456.61, Error: 131.93961548696583
# For strike price 5050, Option price: 453.5431087786141, Actual price: 447.42, Error: 37.492461114741005
# For strike price 5100, Option price: 425.30666412923495, Actual price: 412.0, Error: 177.06731024826803
# Kappa:2.5294189453125,Theta:0.02719921875000006,Total error: 1163.4376656401791
# For strike price 4975, Option price: 497.2211495677736, Actual price: 524.72, Error: 756.1867750939607
# For strike price 5000, Option price: 482.0802588081768, Actual price: 493.1, Error: 121.43469593476595
# For strike price 5025, Option price: 467.25189614473527, Actual price: 456.61, Error: 113.2499535553311
# For strike price 5050, Option price: 452.67799083039927, Actual price: 447.42, Error: 27.646467572562607
# For strike price 5100, Option price: 424.39494617979193, Actual price: 412.0, Error: 153.63469079993857
# Kappa:2.4641799926757812,Theta:0.027047216796875065,Total error: 1172.152582956559
# For strike price 4975, Option price: 496.3598925844108, Actual price: 524.72, Error: 804.2956926237606
# For strike price 5000, Option price: 481.2119830421951, Actual price: 493.1, Error: 141.32494718905807
# For strike price 5025, Option price: 466.37791250461544, Actual price: 456.61, Error: 95.41211469782236
# For strike price 5050, Option price: 451.79953836828554, Actual price: 447.42, Error: 19.18035631928502
# For strike price 5100, Option price: 423.5104946651276, Actual price: 412.0, Error: 132.49148743593148
# Kappa:2.5110931396484375,Theta:0.02689306640625006,Total error: 1192.7045982658576
# For strike price 4975, Option price: 498.82227726218457, Actual price: 524.72, Error: 670.6920430047637
# For strike price 5000, Option price: 483.73144314326413, Actual price: 493.1, Error: 87.7698575778931
# For strike price 5025, Option price: 468.9422894409609, Actual price: 456.61, Error: 152.0853628556355
# For strike price 5050, Option price: 454.4070314264262, Actual price: 447.42, Error: 48.81860815386733
# For strike price 5100, Option price: 426.2121656115437, Actual price: 412.0, Error: 201.9856513699452
# Kappa:2.580638885498047,Theta:0.027351489257812556,Total error: 1161.3515229621048
# For strike price 4975, Option price: 498.85232889295526, Actual price: 524.72, Error: 669.1364085022389
# For strike price 5000, Option price: 483.75212712939765, Actual price: 493.1, Error: 87.38272720494385
# For strike price 5025, Option price: 468.95574861784485, Actual price: 456.61, Error: 152.41750893501762
# For strike price 5050, Option price: 454.413070452038, Actual price: 447.42, Error: 48.90303434716712
# For strike price 5100, Option price: 426.19767074417064, Actual price: 412.0, Error: 201.5738545598788
# Kappa:2.5245628356933594,Theta:0.027352563476562557,Total error: 1159.4135335492463
# For strike price 4975, Option price: 499.283865422258, Actual price: 524.72, Error: 646.9969422570049
# For strike price 5000, Option price: 484.1857388188781, Actual price: 493.1, Error: 79.46405240525684
# For strike price 5025, Option price: 469.39118622961166, Actual price: 456.61, Error: 163.35872143601443
# For strike price 5050, Option price: 454.8500641693808, Actual price: 447.42, Error: 55.20585356111617
# For strike price 5100, Option price: 426.63476710630783, Actual price: 412.0, Error: 214.17640825586977
# Kappa:2.4940967559814453,Theta:0.027429772949218806,Total error: 1159.2019779152622
# For strike price 4975, Option price: 500.0850917455709, Actual price: 524.72, Error: 606.8787047041415
# For strike price 5000, Option price: 485.0107154812896, Actual price: 493.1, Error: 65.43652402464821
# For strike price 5025, Option price: 470.2343827377822, Actual price: 456.61, Error: 185.62380498557718
# For strike price 5050, Option price: 455.7112417376357, Actual price: 447.42, Error: 68.74468955191205
# For strike price 5100, Option price: 427.5374411993453, Actual price: 412.0, Error: 241.41207902311345
# Kappa:2.545316696166992,Theta:0.027582043457031302,Total error: 1168.0958022893924
# For strike price 4975, Option price: 498.5359532382514, Actual price: 524.72, Error: 685.6043048214383
# For strike price 5000, Option price: 483.43171680328624, Actual price: 493.1, Error: 93.47569997185816
# For strike price 5025, Option price: 468.6320942356877, Actual price: 456.61, Error: 144.53074981175516
# For strike price 5050, Option price: 454.08634975135567, Actual price: 447.42, Error: 44.440219007399584
# For strike price 5100, Option price: 425.8656587018933, Actual price: 412.0, Error: 192.25649123739004
# Kappa:2.533393383026123,Theta:0.02729492492675787,Total error: 1160.3074648498414
# For strike price 4975, Option price: 498.99850612232564, Actual price: 524.72, Error: 661.5952472992411
# For strike price 5000, Option price: 483.88650239530455, Actual price: 493.1, Error: 84.88853811172928
# For strike price 5025, Option price: 469.0811626061454, Actual price: 456.61, Error: 155.52989674891964
# For strike price 5050, Option price: 454.5288835698285, Actual price: 447.42, Error: 50.53622560937749
# For strike price 5100, Option price: 426.2878822595749, Actual price: 412.0, Error: 204.14357946347596
# Kappa:2.4468512535095215,Theta:0.02737320861816412,Total error: 1156.6934872327436
# For strike price 4975, Option price: 499.08722803723487, Actual price: 524.72, Error: 657.0389984951198
# For strike price 5000, Option price: 483.96409798476685, Actual price: 493.1, Error: 83.46470563194151
# For strike price 5025, Option price: 469.14985190525596, Actual price: 456.61, Error: 157.2478858057511
# For strike price 5050, Option price: 454.588779326301, Actual price: 447.42, Error: 51.391397029200306
# For strike price 5100, Option price: 426.323811298376, Actual price: 412.0, Error: 205.17157011148313
# Kappa:2.379957437515259,Theta:0.027384068298339906,Total error: 1154.314557073496
# For strike price 4975, Option price: 499.83376525700663, Actual price: 524.72, Error: 619.3246796833715
# For strike price 5000, Option price: 484.7166429839806, Actual price: 493.1, Error: 70.28067485804222
# For strike price 5025, Option price: 469.90677659596224, Actual price: 456.61, Error: 176.80426784292888
# For strike price 5050, Option price: 455.35019627600434, Actual price: 447.42, Error: 62.88801297595285
# For strike price 5100, Option price: 427.0895218764625, Actual price: 412.0, Error: 227.69367046024118
# Kappa:2.340660810470581,Theta:0.02751891632080084,Total error: 1156.9913058205366
# For strike price 4975, Option price: 499.6371717988112, Actual price: 524.72, Error: 629.148270570353
# For strike price 5000, Option price: 484.49488728133525, Actual price: 493.1, Error: 74.0479649009262
# For strike price 5025, Option price: 469.6632701833533, Actual price: 456.61, Error: 170.38786247961968
# For strike price 5050, Option price: 455.0879485779693, Actual price: 447.42, Error: 58.79743539438138
# For strike price 5100, Option price: 426.77397020449416, Actual price: 412.0, Error: 218.27019560328128
# Kappa:2.2265214920043945,Theta:0.02747321166992194,Total error: 1150.6517289485616
# For strike price 4975, Option price: 499.81194749561996, Actual price: 524.72, Error: 620.4110795609541
# For strike price 5000, Option price: 484.6477654121459, Actual price: 493.1, Error: 71.44026952811801
# For strike price 5025, Option price: 469.79419995525126, Actual price: 456.61, Error: 173.82312846004692
# For strike price 5050, Option price: 455.2032640881282, Actual price: 447.42, Error: 60.579199865545974
# For strike price 5100, Option price: 426.8362172057963, Actual price: 412.0, Error: 220.11334097756583
# Kappa:2.092733860015869,Theta:0.027494931030273506,Total error: 1146.3670183922309
# For strike price 4975, Option price: 499.0664169827418, Actual price: 524.72, Error: 658.1063216233583
# For strike price 5000, Option price: 483.8962340990916, Actual price: 493.1, Error: 84.70930675872462
# For strike price 5025, Option price: 469.0389165365927, Actual price: 456.61, Error: 154.477966273587
# For strike price 5050, Option price: 454.44386820616313, Actual price: 447.42, Error: 49.33472457754906
# For strike price 5100, Option price: 426.0732132631421, Actual price: 412.0, Error: 198.05533154987936
# Kappa:2.132030487060547,Theta:0.02736008300781257,Total error: 1144.6836507830983
# For strike price 4975, Option price: 498.6828001297798, Actual price: 524.72, Error: 677.9357770817951
# For strike price 5000, Option price: 483.4855834286305, Actual price: 493.1, Error: 92.43700600782506
# For strike price 5025, Option price: 468.6008560752578, Actual price: 456.61, Error: 143.78062941754678
# For strike price 5050, Option price: 453.98705314770785, Actual price: 447.42, Error: 43.12618704481943
# For strike price 5100, Option price: 425.5621912094781, Actual price: 412.0, Error: 183.93303040244507
# Kappa:2.02771532535553,Theta:0.02728066635131844,Total error: 1141.2126299544313
# For strike price 4975, Option price: 499.4113354200037, Actual price: 524.72, Error: 640.528502822761
# For strike price 5000, Option price: 484.1689361448694, Actual price: 493.1, Error: 79.76390158442055
# For strike price 5025, Option price: 469.22992283758464, Actual price: 456.61, Error: 159.26245242658996
# For strike price 5050, Option price: 454.5754065022585, Actual price: 447.42, Error: 51.19984221256283
# For strike price 5100, Option price: 426.0483660541844, Actual price: 412.0, Error: 197.35658879236013
# Kappa:1.7404917478561401,Theta:0.027391529083252042,Total error: 1128.1112878386944
# For strike price 4975, Option price: 499.5831659050258, Actual price: 524.72, Error: 631.8604283182591
# For strike price 5000, Option price: 484.26220864357725, Actual price: 493.1, Error: 78.10655605966102
# For strike price 5025, Option price: 469.23878495132055, Actual price: 456.61, Error: 159.48620934670015
# For strike price 5050, Option price: 454.5180332590366, Actual price: 447.42, Error: 50.3820761463895
# For strike price 5100, Option price: 425.852184460425, Actual price: 412.0, Error: 191.88301432564006
# Kappa:1.4207589030265808,Theta:0.027395259475708117,Total error: 1111.7182841966498
# For strike price 4975, Option price: 498.45638891917343, Actual price: 524.72, Error: 689.7772670049173
# For strike price 5000, Option price: 483.10248529712743, Actual price: 493.1, Error: 99.95030023415367
# For strike price 5025, Option price: 468.03874820093466, Actual price: 456.61, Error: 130.61628544036697
# For strike price 5050, Option price: 453.2851923497309, Actual price: 447.42, Error: 34.40048129934159
# For strike price 5100, Option price: 424.5584671766495, Actual price: 412.0, Error: 157.71509782698323
# Kappa:1.3557403683662415,Theta:0.027180994796753052,Total error: 1112.4594318057627
# For strike price 4975, Option price: 499.21089666487313, Actual price: 524.72, Error: 650.714352962182
# For strike price 5000, Option price: 483.78480220007253, Actual price: 493.1, Error: 86.77291005177393
# For strike price 5025, Option price: 468.6455706705472, Actual price: 456.61, Error: 144.85496136573602
# For strike price 5050, Option price: 453.78695329763644, Actual price: 447.42, Error: 40.53809429428338
# For strike price 5100, Option price: 424.8754090597189, Actual price: 412.0, Error: 165.7761584550913
# Kappa:1.0,Theta:0.027295587921142728,Total error: 1088.6564771290666
# For strike price 4975, Option price: 499.25104541854205, Actual price: 524.72, Error: 648.6676474723694
# For strike price 5000, Option price: 483.8256957573604, Actual price: 493.1, Error: 86.01271918504344
# For strike price 5025, Option price: 468.6870176398269, Actual price: 456.61, Error: 145.8543550726892
# For strike price 5050, Option price: 453.82908770344676, Actual price: 447.42, Error: 41.07640519047226
# For strike price 5100, Option price: 424.9186209100357, Actual price: 412.0, Error: 166.89076621721196
# Kappa:1.0,Theta:0.027303048706054878,Total error: 1088.5018931377863
# For strike price 4975, Option price: 500.38052540651915, Actual price: 524.72, Error: 592.4100234867009
# For strike price 5000, Option price: 484.9944705514771, Actual price: 493.1, Error: 65.69960764087243
# For strike price 5025, Option price: 469.8855181950507, Actual price: 456.61, Error: 176.23938334712128
# For strike price 5050, Option price: 455.0677193593341, Actual price: 447.42, Error: 58.48761139913321
# For strike price 5100, Option price: 426.229445240953, Actual price: 412.0, Error: 202.47711186527994
# Kappa:1.0650185346603394,Theta:0.027517313385009942,Total error: 1095.3137377391076
# For strike price 4975, Option price: 499.9070302306013, Actual price: 524.72, Error: 615.683468777094
# For strike price 5000, Option price: 484.49385836735405, Actual price: 493.1, Error: 74.06567380116228
# For strike price 5025, Option price: 469.36442918340674, Actual price: 456.61, Error: 162.67546379453722
# For strike price 5050, Option price: 454.51769794948, Actual price: 447.42, Error: 50.3773161820525
# For strike price 5100, Option price: 425.62472658902556, Actual price: 412.0, Error: 185.63317462569998
# Kappa:1.0,Theta:0.027425102615356703,Total error: 1088.4350971805459
# For strike price 4975, Option price: 499.9871194977395, Actual price: 524.72, Error: 611.7153779390983
# For strike price 5000, Option price: 484.57544370205875, Actual price: 493.1, Error: 72.66806007677023
# For strike price 5025, Option price: 469.4471785870267, Actual price: 456.61, Error: 164.7931540752168
# For strike price 5050, Option price: 454.6017881267446, Actual price: 447.42, Error: 51.578080697449806
# For strike price 5100, Option price: 425.71094707641106, Actual price: 412.0, Error: 187.99006973214497
# Kappa:1.0,Theta:0.02744002418518099,Total error: 1088.74474252068
# For strike price 4975, Option price: 498.75440929912963, Actual price: 524.72, Error: 674.2119004451271
# For strike price 5000, Option price: 483.32002911088375, Actual price: 493.1, Error: 95.64783059196171
# For strike price 5025, Option price: 468.1744826372467, Actual price: 456.61, Error: 133.73725866717967
# For strike price 5050, Option price: 453.3079308641902, Actual price: 447.42, Error: 34.66772986148351
# For strike price 5100, Option price: 424.3841090152146, Actual price: 412.0, Error: 153.36615610072002
# Kappa:1.0,Theta:0.02721083793640164,Total error: 1091.630875666472
# For strike price 4975, Option price: 499.1671334465529, Actual price: 524.72, Error: 652.9489890982771
# For strike price 5000, Option price: 483.74023551475943, Actual price: 493.1, Error: 87.60519121917103
# For strike price 5025, Option price: 468.6003924281433, Actual price: 456.61, Error: 143.7695105808764
# For strike price 5050, Option price: 453.74102609910665, Actual price: 447.42, Error: 39.955370945587205
# For strike price 5100, Option price: 424.828307155181, Actual price: 412.0, Error: 164.56546446766788
# Kappa:1.0,Theta:0.027287456798553718,Total error: 1088.8445263115796
# For strike price 4975, Option price: 499.99071684699226, Actual price: 524.72, Error: 611.5374452616339
# For strike price 5000, Option price: 484.57910880812716, Actual price: 493.1, Error: 72.60558670373655
# For strike price 5025, Option price: 469.4508954264662, Actual price: 456.61, Error: 164.88859535344068
# For strike price 5050, Option price: 454.60556527224685, Actual price: 447.42, Error: 51.63234828171971
# For strike price 5100, Option price: 425.71481983425076, Actual price: 412.0, Error: 188.09628308595808
# Kappa:1.0,Theta:0.027440694522857863,Total error: 1088.760258686489
# For strike price 4975, Option price: 499.78504932457486, Actual price: 524.72, Error: 621.7517651858861
# For strike price 5000, Option price: 484.3696196279608, Actual price: 493.1, Error: 76.21954144048793
# For strike price 5025, Option price: 469.2384149932802, Actual price: 456.61, Error: 159.47686524250312
# For strike price 5050, Option price: 454.3896371416309, Actual price: 447.42, Error: 48.57584188600052
# For strike price 5100, Option price: 425.4934086119704, Actual price: 412.0, Error: 182.07207596959643
# Kappa:1.0,Theta:0.02740238509178183,Total error: 1088.096089724474
# For strike price 4975, Option price: 500.4398264312247, Actual price: 524.72, Error: 589.5268285298573
# For strike price 5000, Option price: 485.0367678878477, Actual price: 493.1, Error: 65.01571209444437
# For strike price 5025, Option price: 469.91501833772094, Actual price: 456.61, Error: 177.02351296709006
# For strike price 5050, Option price: 455.07702946910507, Actual price: 447.42, Error: 58.630100290743236
# For strike price 5100, Option price: 426.1982847356597, Actual price: 412.0, Error: 201.59128943486678
# Kappa:1.0,Theta:0.02752443900108366,Total error: 1091.7874433170018
# For strike price 4975, Option price: 499.54869112074385, Actual price: 524.72, Error: 633.5947906949207
# For strike price 5000, Option price: 484.1288947232888, Actual price: 493.1, Error: 80.48072988583604
# For strike price 5025, Option price: 468.994308962654, Actual price: 456.61, Error: 153.37110848247121
# For strike price 5050, Option price: 454.1415145610619, Actual price: 447.42, Error: 45.17875799456708
# For strike price 5100, Option price: 425.2389937559125, Actual price: 412.0, Error: 175.2709556690895
# Kappa:1.0,Theta:0.027358396279812073,Total error: 1087.8963427268843
# For strike price 4975, Option price: 499.4265636947408, Actual price: 524.72, Error: 639.7579201282044
# For strike price 5000, Option price: 484.0044885159865, Actual price: 493.1, Error: 82.72832915582171
# For strike price 5025, Option price: 468.86821235724625, Actual price: 456.61, Error: 150.26377019534434
# For strike price 5050, Option price: 454.0133158558976, Actual price: 447.42, Error: 43.47181397563033
# For strike price 5100, Option price: 425.1075318892045, Actual price: 412.0, Error: 171.80739222651275
# Kappa:1.0,Theta:0.0273356787562372,Total error: 1088.0292256815135
# For strike price 4975, Option price: 499.18991796018724, Actual price: 524.72, Error: 651.7850889595712
# For strike price 5000, Option price: 483.7634376541911, Actual price: 493.1, Error: 87.17139643717739
# For strike price 5025, Option price: 468.62391363944823, Actual price: 456.61, Error: 144.33412093611997
# For strike price 5050, Option price: 453.7649372355435, Actual price: 447.42, Error: 40.25822852298654
# For strike price 5100, Option price: 424.85282987201185, Actual price: 412.0, Error: 165.1952357188802
# Kappa:1.0,Theta:0.02729168994426744,Total error: 1088.7440705747354
# For strike price 4975, Option price: 499.6363775035953, Actual price: 524.72, Error: 629.1881175421399
# For strike price 5000, Option price: 484.218203032775, Actual price: 493.1, Error: 78.88631736700721
# For strike price 5025, Option price: 469.0848506970461, Actual price: 456.61, Error: 155.6218999135907
# For strike price 5050, Option price: 454.23355621949526, Actual price: 447.42, Error: 46.42454835622227
# For strike price 5100, Option price: 425.3333744429864, Actual price: 412.0, Error: 177.77887403688243
# Kappa:1.0,Theta:0.02737471130490323,Total error: 1087.8997572158426
# For strike price 4975, Option price: 499.7584291395205, Actual price: 524.72, Error: 623.0800198227406
# For strike price 5000, Option price: 484.3425079497312, Actual price: 493.1, Error: 76.69366701052138
# For strike price 5025, Option price: 469.210915789195, Actual price: 456.61, Error: 158.78307872638314
# For strike price 5050, Option price: 454.3616902388543, Actual price: 447.42, Error: 48.18706337220476
# For strike price 5100, Option price: 425.46475096115836, Actual price: 412.0, Error: 181.29951844601496
# Kappa:1.0,Theta:0.027397428828478107,Total error: 1088.0433473778648
# For strike price 4975, Option price: 499.50956078555276, Actual price: 524.72, Error: 635.5662453853403
# For strike price 5000, Option price: 484.08903422095665, Actual price: 493.1, Error: 81.19750427109076
# For strike price 5025, Option price: 468.95390457002253, Actual price: 456.61, Error: 152.37198003382278
# For strike price 5050, Option price: 454.1004388595588, Actual price: 447.42, Error: 44.62826335630278
# For strike price 5100, Option price: 425.1968717542216, Actual price: 412.0, Error: 174.157424097372
# Kappa:1.0,Theta:0.027351116274297427,Total error: 1087.9214171439287
# For strike price 4975, Option price: 499.67549621849264, Actual price: 524.72, Error: 627.2271696619379
# For strike price 5000, Option price: 484.2580439136044, Actual price: 493.1, Error: 78.18018743374842
# For strike price 5025, Option price: 469.12525372971464, Actual price: 456.61, Error: 156.63157591913594
# For strike price 5050, Option price: 454.27462430304325, Actual price: 447.42, Error: 46.985874335870996
# For strike price 5100, Option price: 425.3754797722248, Actual price: 412.0, Error: 178.90345913719537
# Kappa:1.0,Theta:0.02738199131041788,Total error: 1087.9282664878885
# For strike price 4975, Option price: 499.5510492483476, Actual price: 524.72, Error: 633.4760819391041
# For strike price 5000, Option price: 484.13129685423377, Actual price: 493.1, Error: 80.43763611687753
# For strike price 5025, Option price: 468.99674395830596, Actual price: 456.61, Error: 153.43142588862875
# For strike price 5050, Option price: 454.1439899258918, Actual price: 447.42, Error: 45.21204052349403
# For strike price 5100, Option price: 425.2415321761247, Actual price: 412.0, Error: 175.33817437134516
# Kappa:1.0,Theta:0.02735883503332754,Total error: 1087.8953588394495
# For strike price 4975, Option price: 499.4633477969675, Actual price: 524.72, Error: 637.8984805049465
# For strike price 5000, Option price: 484.04195894315865, Actual price: 493.1, Error: 82.04810778742402
# For strike price 5025, Option price: 468.9061909001599, Actual price: 456.61, Error: 151.19631065317512
# For strike price 5050, Option price: 454.05192850351597, Actual price: 447.42, Error: 43.982475675747324
# For strike price 5100, Option price: 425.1471257869465, Actual price: 412.0, Error: 172.84691645779372
# Kappa:1.0,Theta:0.027342520008236386,Total error: 1087.9722910790867
# For strike price 4975, Option price: 499.59312600753316, Actual price: 524.72, Error: 631.359796633308
# For strike price 5000, Option price: 484.1741531113122, Actual price: 493.1, Error: 79.6707426802982
# For strike price 5025, Option price: 469.0401873584677, Actual price: 456.61, Error: 154.5095577666093
# For strike price 5050, Option price: 454.18815611890955, Actual price: 447.42, Error: 45.80793724993252
# For strike price 5100, Option price: 425.2868209717434, Actual price: 412.0, Error: 176.5396115351601
# Kappa:1.0,Theta:0.02736666348073652,Total error: 1087.887645865308
# For strike price 4975, Option price: 499.5954841927501, Actual price: 524.72, Error: 631.2412945487504
# For strike price 5000, Option price: 484.17655482782425, Actual price: 493.1, Error: 79.62787374082714
# For strike price 5025, Option price: 469.0426223130496, Actual price: 456.61, Error: 154.57009757893857
# For strike price 5050, Option price: 454.1906313814191, Actual price: 447.42, Error: 45.841449303057026
# For strike price 5100, Option price: 425.2893591848174, Actual price: 412.0, Error: 176.6070675430902
# Kappa:1.0,Theta:0.027367102234251987,Total error: 1087.8877827146632
# For strike price 4975, Option price: 499.63755639995395, Actual price: 524.72, Error: 629.1289769494924
# For strike price 5000, Option price: 484.2194036921554, Actual price: 493.1, Error: 78.8649907829031
# For strike price 5025, Option price: 469.0860680887307, Actual price: 456.61, Error: 155.65227495464447
# For strike price 5050, Option price: 454.2347938614767, Actual price: 447.42, Error: 46.44141537442034
# For strike price 5100, Option price: 425.334643342992, Actual price: 412.0, Error: 177.8127130848015
# Kappa:1.0,Theta:0.027374930681660962,Total error: 1087.9003711462617
# For strike price 4975, Option price: 499.5726767168033, Actual price: 524.72, Error: 632.3878683096082
# For strike price 5000, Option price: 484.1533263382704, Actual price: 493.1, Error: 80.04296960948648
# For strike price 5025, Option price: 469.01907484242076, Actual price: 456.61, Error: 153.98513844479956
# For strike price 5050, Option price: 454.16669159155225, Actual price: 447.42, Error: 45.51784743152163
# For strike price 5100, Option price: 425.264811561758, Actual price: 412.0, Error: 175.95522576894857
# Kappa:1.0,Theta:0.027362858945410896,Total error: 1087.8890495643643
# For strike price 4975, Option price: 499.61593166376326, Actual price: 524.72, Error: 630.2142470304453
# For strike price 5000, Option price: 484.1973797568022, Actual price: 493.1, Error: 79.25664719459554
# For strike price 5025, Option price: 469.0637372329472, Actual price: 456.61, Error: 155.09557106729443
# For strike price 5050, Option price: 454.2120940255032, Actual price: 447.42, Error: 46.13254125127573
# For strike price 5100, Option price: 425.3113676722211, Actual price: 412.0, Error: 177.19250930505248
# Kappa:1.0,Theta:0.027370906769577607,Total error: 1087.8915158486636
# For strike price 4975, Option price: 499.5834911379978, Actual price: 524.72, Error: 631.8440777695174
# For strike price 5000, Option price: 484.1643403865155, Actual price: 493.1, Error: 79.84601272805828
# For strike price 5025, Option price: 469.0302395840044, Actual price: 456.61, Error: 154.26235132406924
# For strike price 5050, Option price: 454.17804290840013, Actual price: 447.42, Error: 45.67114395177707
# For strike price 5100, Option price: 425.2764505653344, Actual price: 412.0, Error: 176.2641396137685
# Kappa:1.0,Theta:0.027364870901452572,Total error: 1087.8877253871904
# For strike price 4975, Option price: 499.5811328424207, Actual price: 524.72, Error: 631.9626419664212
# For strike price 5000, Option price: 484.16193855816687, Actual price: 493.1, Error: 79.8889423379846
# For strike price 5025, Option price: 469.02780489387123, Actual price: 456.61, Error: 154.20187838225203
# For strike price 5050, Option price: 454.17556753167594, Actual price: 447.42, Error: 45.63769267503391
# For strike price 5100, Option price: 425.27391242814434, Actual price: 412.0, Error: 176.19675115004483
# Kappa:1.0,Theta:0.027364432147937105,Total error: 1087.8879065117367
# For strike price 4975, Option price: 499.5918964305108, Actual price: 524.72, Error: 631.4215889989765
# For strike price 5000, Option price: 484.172900836761, Actual price: 493.1, Error: 79.69309947030257
# For strike price 5025, Option price: 469.0389177533515, Actual price: 456.61, Error: 154.47799651957536
# For strike price 5050, Option price: 454.18686549695786, Actual price: 447.42, Error: 45.79046865391859
# For strike price 5100, Option price: 425.28549752693306, Actual price: 412.0, Error: 176.50444453814436
# Kappa:1.0,Theta:0.027366434712673266,Total error: 1087.8875981809174
# For strike price 4975, Option price: 499.60153098405823, Actual price: 524.72, Error: 630.9374857048281
# For strike price 5000, Option price: 484.1827132413418, Actual price: 493.1, Error: 79.5180031361415
# For strike price 5025, Option price: 469.0488663325397, Actual price: 456.61, Error: 154.72539563878973
# For strike price 5050, Option price: 454.1969783804429, Actual price: 447.42, Error: 45.92743596899006
# For strike price 5100, Option price: 425.29586760079934, Actual price: 412.0, Error: 176.7800952579856
# Kappa:1.0,Theta:0.02736822729195721,Total error: 1087.8884157067348
# For strike price 4975, Option price: 499.5880012185635, Actual price: 524.72, Error: 631.6173627501282
# For strike price 5000, Option price: 484.1689337208655, Actual price: 493.1, Error: 79.7639448822941
# For strike price 5025, Option price: 469.0348957645421, Actual price: 456.61, Error: 154.3780347597362
# For strike price 5050, Option price: 454.1827768996194, Actual price: 447.42, Error: 45.73515139402554
# For strike price 5100, Option price: 425.28130494948823, Actual price: 412.0, Error: 176.39306116130058
# Kappa:1.0,Theta:0.02736570999907873,Total error: 1087.8875549474847
# Best parameters: [1.         0.02736571]
# Best error: 1087.8875549474847

# %%
kappa, theta = 0, 0.02734852
total_error = 0
for i in range(len(actual_price_list)):
    option_price = monte_carlo_simulation(S0=S0, strike=actual_strike_list[i], r=r, kappa=kappa, theta=theta, volvol=volvol, rho=rho_hat, maturity=1, n_steps=250, n_simulations=10000)
    error = (option_price - actual_price_list[i])**2
    total_error += error
    print(f"For strike price {actual_strike_list[i]}, Option price: {option_price}, Actual price: {actual_price_list[i]}, Error: {error}")
print(f"Kappa:{kappa},Theta:{theta},Total error: {total_error}")
# Out:
# For strike price 4975, Option price: 499.56102530464045, Actual price: 524.72, Error: 632.9740077217434
# For strike price 5000, Option price: 483.7728948224795, Actual price: 493.1, Error: 86.9948909925304
# For strike price 5025, Option price: 468.27073627763855, Actual price: 456.61, Error: 135.97277053663538
# For strike price 5050, Option price: 453.0343193164271, Actual price: 447.42, Error: 31.520581386806455
# For strike price 5100, Option price: 423.34782184257404, Actual price: 412.0, Error: 128.77306057080037
# Kappa:0,Theta:0.02734852,Total error: 1016.235311208516

# %%
r
# Out:
# 0.05097824494588458
